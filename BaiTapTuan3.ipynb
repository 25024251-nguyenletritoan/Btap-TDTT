# %%
#w3a2
a=float(input("a="))
b=float(input("b="))
a, b=b, a
print(a,b)
# Out:
# 4.0 3.0

# %%
#w3a3
n=int(input("n="))
if n&(n-1)==0:
    print("Luy thua cua 2 la:", n)
else:
    print("Day khong phai luy thua cua 2")
# Out:
# Day khong phai luy thua cua 2

# %%
#w3a4
a, b = map(int, input("nhap 1 day:").split())
x=a/b
print(int(x))
# Out:
# 5

# %%
#w3a5
m=float(input("m="))
n=float(input("n="))
x=m/n
import math
print(math.ceil(x))
# Out:
# 3

# %%
m=float(input("m="))
n=float(input("n="))
x=m/n
print(int(x+0.5))
# Out:
# 5

# %%
#w3a6
x=int(input("x="))
while x<=0:
    x=int(input("Nhap lai x="))
if x%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
#w3a7
a=int(input("a="))
b=int(input("b="))
if a<0 and b<0:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#w3a8
a=str(input("Nhap chuoi a:"))
b=str(input("Nhap chuoi b:"))
if len(a)>len(b):
    print(True)
else:
    print(False)
# Out:
# True

# %%
#w3a9
a, b, c = map(int, input("Nhap 3 so:").split())
if a+b>c and a+c>b and b+c>a:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#w3a10
a, b, c, d = map(int, input("Nhap 4 so a b c d:").split())
print(max(a, b, c, d))
# Out:
# 6

# %%
#w3a10 cach 2
a, b, c, d = map(int, input("Nhap 4 so :").split())
if a>b>c>d:
    print(a)
elif b>a>c>d:
    print(b)
elif c>a>b>d:
    print(c)
else:
    print(d)
# Out:
# 4

# %%
#w3a10 cach 3
lst=list(map(int, input("Nhap mot chuoi:").split()))
a=lst[0]
for i in range(len(lst)):
    if lst[i]>a:
        a=lst[i]
print(a)
# Out:
# 45

# %%
#w3a11
a, b, c = map(int, input("Nhap 3 so:").split())
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
        print("Day la tam giac deu")
    elif a==b or a==c or b==c:
        print("Day la tam giac can")
    else:
        print("Day la tam giac thuong")
else:
    print("Khong phai tam giac")
# Out:
# Day la tam giac can

# %%
#w3a12
n=int(input("Nhap nam:"))
if n%400==0 or (n%4==0 and n%100!=0):
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#w3a14
a, b = map(int, input("Nhap a va b:").split())
if a==0 and b!=0:
    print("Vo nghiem")
elif a==0 and b==0:
    print("Vo so nghiem")
else:
    x=(-b)/a
    print("Nghiem cua phuong trinh la:", f"{x:.2f}")
# Out:
# Nghiem cua phuong trinh la: -3.33

# %%
#w3a15
a=float(input("Nhap diem trung binh cua hoc sinh"))
print("Diem trung binh cua hoc sinh la:", a)
if a>=8:
    print("Gioi")
elif a>=6.5 and a<8:
    print("Kha")
elif a>=5 and a<6.5:
    print("Trung binh")
else:
    print("Yeu")
# Out:
# Diem trung binh cua hoc sinh la: 7.5
# Kha

# %%
#w3a16
a=float(input("a="))
if a.is_integer():
    print(a, a, a, end=" ")
elif a>0:
    a1=int(a+1)
    a2=int(a)
    a3=int(a+0.5)
    print(a1, a2, a3, end=" ")
elif a<0:
    a1=int(a-1)
    a2=int(a)
    a3=int(a-0.5)
    print(a1, a2, a3, end=" ")
# Out:
# 8 7 8

# %%
#w3a17
lst = list(map(int, input("Nhap mot chuoi: ").split()))
print(a, b, c, d)
if b/a==c/b==d/c:
    print("Day la cap so nhan")
else:
    print("Day khong phai cap so nhan")
# Out:
# 1.5 2.0 3 4
# Day khong phai cap so nhan

# %%
#w3a18 cach 2
lst = list(map(int, input("Nhap mot chuoi: ").split()))
a=sorted(lst)
ok = False
for i in range(len(a)-1):
    if a[i+1]/a[i]==a[i]/a[i-1]:
        ok = True
        break
if ok:
    print("La cap so nhan")
else:
    print("Khong phai cap so nhan")
# Out:
# La cap so nhan
