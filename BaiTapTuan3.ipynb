# %%
#w3a2
a=float(input("a="))
b=float(input("b="))
a, b=b, a
print(a,b)
# Out:
# 4.0 3.0

# %%
#w3a3
n=int(input("n="))
if n&(n-1)==0:
    print("Luy thua cua 2 la:", n)
else:
    print("Day khong phai luy thua cua 2")
# Out:
# Day khong phai luy thua cua 2

# %%
a, b, c, d = map(int, input("nhap 1 day:").split())
x=b/a
y=c/b
z=d/c
if x==y==z:
    print("Day la 3 so cong boi cua nhau")
else:
    print("Day khong la 3 so cong boi cua nhau")
# Out:
# Day khong la 3 so cong boi cua nhau
