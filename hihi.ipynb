# %%
#Bai1
n=int(input("n="))
print("so gap doi của n la:", 2*n)
# Out:
# so gap doi của n la: 14

# %%
#Bai2
a=float(input("Nhap chieu dai cua hcn la:"))
b=float(input("Nhap chieu rong cua hcn la:"))
Shcn=a*b
Stron=((b/2)**2)*3.14
Sconlai=Shcn-Stron
print("Dien tich con lai la:", Sconlai)
# Out:
# Dien tich con lai la: -4.260000000000002

# %%
#Bai3
n=input("nhap mot ky tu:")
if n.isupper():
    print(n.lower())
else:
    print(n.upper())
# Out:
# A

# %%
#Bai4
n=input("nhap n:")
if n.isalpha():
    print(n)
else:
    print("Day khong phai chu thuoc alphabet:", n)
# Out:
# Day khong phai chu thuoc alphabet: 5

# %%
#Bai6
a=float(input("a="))
b=float(input("b="))
c=float(input("c="))
if a+b>c and b+c>a and a+c>b:
    C=(a+b+c)/2
    S=(C*(C-a)*(C-b)*(C-c))**(1/2)
    print("Dien tich cua tam giac la:", S)
else:
    print("Day khong phai la tam giac")
# Out:
# Day khong phai la tam giac

# %%
#Bai7
Nhap=str(input("Nhap vao mot chuoi:"))
if len(Nhap)<=20:
    print("Loi")
else:
    print(Nhap[4] ,"va", Nhap[8])
# Out:
# Loi

# %%
#Bai8
a=input("Ten chu ho:")
b=int(input("Chi so thang truoc:"))
c=int(input("Chi so thang nay:"))
print("Ho va ten:", a)
if c<=50:
    x=(c*1.984)*(1+0.08)
    print("Tien phai tra la:", f"{x:.1f}")
elif 51<=c<=100:
    y=(50*1.984+(c-50)*2.050)*(1+0.08)
    print("Tien phai tra la:", f"{y:.1f}")
elif 101<=c<=200:
    z=(50*1.984+50*2.050+(c-100)*2.380)*(1+0.08)
    print("Tien phai tra la:", f"{z:.1f}")
elif 201<=c<=300:
    h=(50*1.984+50*2.050+100*2.380+(c-200)*2.998)*(1+0.08)
    print("Tien phai tra la:", f"{h:.1f}")
elif 301<=c<=400:
    k=(50*1.984+50*2.050+100*2.380+100*2.998 +(c-300)*3.350)*(1+0.08)
    print("Tien phai tra la:", f"{k:.1f}")
else:
    l=(50*1.984+50*2.050+100*2.380+100*2.998+100*3.350+(c-400)*3.460)*(1+0.08)
    print("Tien phai tra la:", f"{l:.1f}")
# Out:
# Ho va ten: Tri Toan
# Tien phai tra la: 3402.5

# %%
#Mot so bai tap khac 1
n=int(input("nhap so nguyen n:"))
if n%2==0:
    print("day la so chan:", n)
else:
    print("day la so le:",)
# Out:
# day la so chan: 4

# %%
#Mot so bai tap khac 2
n=int(input("Nhap n="))
if n%5==0 and n%10!=0:
    print(True)
elif n%5==0 and n%10==0:
    print(False)
else:
    print(False)
# Out:
# True

# %%
#Mot so bai tap khac 3
n=int(input("Nhap n="))
if n%3==0 and n%5==0:
    print(True)
else:
    print(False)
# Out:
# True

# %%
#Mot so bai tap khac bai 4
a=int(input("Nhap nam sinh cua ban:"))
while a>=2025 or a<=1900:
    a=int(input("Nhap lai nam sinh cua ban la:"))
b=2025-a
if b>=18:
    print("Ban du tuoi de di bau cu")
else:
    print("ban khong du tuoi de di bau cu")

# %%
#Mot so bai tap khac bai 5
a=float(input("a="))
b=float(input("b="))
if a==b:
    print("Hai so nay bang nhau")
else:
    print(max(a,b))
# Out:
# 11.3

# %%
#Mot so bai tap khac bai 6
a=input("Nhap a la:")

if a.isalpha():
    print(a ,"la chu cai")
elif a.isdigit():
    print(a ,"la so")
else:
    print("Day khong phai so hoac chu")
# Out:
# Day khong phai so hoac chu

# %%
#Mot so bai tap khac bai 7
a=float(input("Nhap diem tong ket cua ban la:"))
while a<0 or a>10:
    a=float(input("Nhap lai diem cua ban la:"))
if a>=8:
    print("Giỏi")
elif a>=6.5 and a<8:
    print("Khá")
elif a>=5 and a<6.5:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Yếu

# %%
#Mot so bai tap khac, bai 8
n=int(input("Nhap nam:"))
if n%400==0:
    print("Day la nam nhuan")
elif n%4==0 and n%100!=0:
    print("Day la nam nhuan")
else:
    print("Day la nam khong nhuan")
# Out:
# Day la nam nhuan

# %%
#Mot so bai tap khac, bai 9

# %%
#Mot so bai tap khac, bai 10
a=float(input("Nhập điểm thi của bạn:"))
while a<=0 or a>10:
    a=float(input("Nhap lai diem cua ban la:"))
if a>=4:
    print("Qua môn")
else:
    print("Hoc lai")
# Out:
# Hoc lai

# %%
#Mot so bai tap khac, bai 11
a=int(input("Nhap nam sinh cua ban"))
while a>=2025:
    a=int(input("Nhap lai nam sinh cua ban la:"))
Tuoi=2025-a
if Tuoi>=18:
    print("Nguoi do da du 18 tuoi")
else:
    print("Nguoi do chua du 18 tuoi")
# Out:
# Nguoi do da du 18 tuoi
