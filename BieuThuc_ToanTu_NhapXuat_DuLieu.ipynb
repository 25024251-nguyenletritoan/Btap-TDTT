# %%
#w2a1
print("Hello world")

# %%
#w2a2
n=input("nhap n:")
print(n)

# %%
#w2a3
a=int(input("a="))
b=int(input("b="))
print("Tong cua a va b la:", a+b)
print("Hieu cua a va b la:",a-b)
print("Tich cua a va b la:", a*b)
print("Phep chia lay phan nguyen cua a va b la:", a//b)
print("Phep chia lay phan du cua a va b la:", a%b)
print("Pheo chia cua a va b la:", a/b)
# Out:
# Tong cua a va b la: 13
# Hieu cua a va b la: 7
# Tich cua a va b la: 30
# Phep chia lay phan nguyen cua a va b la: 3
# Phep chia lay phan du cua a va b la: 1
# Pheo chia cua a va b la: 3.3333333333333335

# %%
#w2a4
a1, b1, c1, a2, b2, a3 =map(float, input("Nhap diem:").split())
TB=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(f"{TB:.1f}")
# Out:
# 4.2

# %%
#w2a5
a, b =map(int, input("Nhap a va b la:").split())
print("Luy thua cua hai so la:", a**b)
# Out:
# Luy thua cua hai so la: 8

# %%
#w2a6
a=input("Nhap a la:")
print(a.upper())
# Out:
# TOÀN

# %%
#w2a7
A=((13**2)*3)+5
B=13**2*3+5
print(A)
print(B)
# Out:
# 512
# 512

# %%
#w2a8
C=float(input("Nhap do c:"))
F=(9/5)*C+32
print(f"{F:.2f}")
# Out:
# 32.00

# %%
#w2a9
x=float(input("Nhap gia cua chiec dong ho:"))
P=10+0.4*x
print("Gia cua chiec dong ho la:", f"{P:.2f}")
# Out:
# Gia cua chiec dong ho la: 27.60

# %%
#w2a10
a=str(input("Nhap ten cua 3 nguoi:")).split()
a.reverse()
print(f"Hi {a[0]}, {a[1]} and {a[2]}")
# Out:
# Hi duy, hieu and toan

# %%
#w2a11
h=int(input("Nhap so gio:"))
m=int(input("Nhap so phut:"))
s=3600*h+60*m
print("So giay la:", s)
# Out:
# So giay la: 57360

# %%
#w2a12
n=int(input("n="))
#so o vuong nho cua 1 mat
S=n*n 
#tong so o vuong
a=6*S
print("Tong so mieng dan can thiet la:", a)
# Out:
# Tong so o vuông la: 24

# %%
#w2a13
a=int(input("a="))
b=int(input("b="))
tich=a*b
x=tich%10
print("Hang don vi cua tich a b la:", x)
# Out:
# Hang don vi cua tich a b la: 5

# %%
#w2a14
a,b=input("nhap a,b").split(",")
a, b = b, a
print("Sau khi hoán đổi: a =", a, ", b =", b)
# Out:
# Sau khi hoán đổi: a = 4 , b = 3

# %%
#w2a15
n=int(input("nhap n la:"))
P=3*n*(n-z)+1
print("Số sao thứ ",n , "la", P)

# %%
#w2a16
print("Spring")
print("Summer")
print("Autumn")
print("Winter")
#
print("Spring/nSummer/nAutumn/nwinter")

# %%
#w2a17
n=int(input("n="))
len=2*n-1
for i in range (0, n):
    P=2*i+1
    N=n-i
    stars="*" * (P)
    line=stars.center(len)
    line=line.replace(" ", "#")
    print(line)
