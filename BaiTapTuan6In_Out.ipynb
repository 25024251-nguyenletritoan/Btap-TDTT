# %%
#w6a1
lst = list(map(int, input().split()))
lst1 = []
for i in range(len(lst)):
        if lst[i] not in lst1:
            lst1.append(lst[i])
print(lst1)
# Out:
# [1]

# %%
#w6a2
lst = list(map(int, input().split()))
tong = 0 
lst1 = []
for i in lst:
    tong = tong + i
    lst1.append(tong)
print(lst1)
# Out:
# [10, 5, 15]

# %%
#w6a3
lst = list(map(int, input().split()))
k = int(input())
print(tuple(lst[k::])+tuple(lst[0:k]))
# Out:
# (5, 6)

# %%
#w
